# %% [markdown]
# <a href="https://colab.research.google.com/github/ramya-njn/Fine-Tune-ChemBERTa/blob/main/Deploy_FTChemBERTa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers

# %%
# !pip install huggingface_hub

# %%
import os
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# %%
from google.colab import drive
drive.mount('/content/drive')

os.chdir('/content/drive/My Drive/ChemBERTa')
# !pwd
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/ChemBERTa

# %%
model = AutoModelForSequenceClassification.from_pretrained('/content/drive/My Drive/ChemBERTa/output')

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
model.push_to_hub('ramyanjn/ChemBERTaFTTox')
# Out:
# model.safetensors:   0%|          | 0.00/13.7M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/ramyanjn/ChemBERTaFTTox/commit/eb9c3d56953a2f9ee3efd43ff70cad1450ca3cd3', commit_message='Upload RobertaForSequenceClassification', commit_description='', oid='eb9c3d56953a2f9ee3efd43ff70cad1450ca3cd3', pr_url=None, pr_revision=None, pr_num=None)

# %%
model = AutoModelForSequenceClassification.from_pretrained('ramyanjn/ChemBERTaFTTox')
# Out:
# config.json:   0%|          | 0.00/9.10k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/13.7M [00:00<?, ?B/s]
